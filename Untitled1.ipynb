# %% [markdown]
# <a href="https://colab.research.google.com/github/Fatmaahmedali/python/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as num
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/instagram_usage_lifestyle.csv")

# %%
df
# Out:
#       user_id   app_name  age      gender         country urban_rural  \
# 0           1  Instagram   51      Female           India       Rural
# 1           2  Instagram   64      Female  United Kingdom       Urban
# 2           3  Instagram   41      Female          Canada       Urban
# 3           4  Instagram   27  Non-binary     South Korea       Urban
# 4           5  Instagram   55        Male           India       Urban
# ...       ...        ...  ...         ...             ...         ...
# 7424    18576  Instagram   37        Male   United States    Suburban
# 7425    18577  Instagram   44        Male          Brazil       Urban
# 7426    18578  Instagram   20      Female       Australia       Urban
# 7427    18579  Instagram   17        Male           Other    Suburban
# 7428    18580  Instagram   42        Male           India       Urban
#
#       income_level   employment_status education_level relationship_status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7429 entries, 0 to 7428
# Data columns (total 58 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   user_id                         7429 non-null   int64
#  1   app_name                        7429 non-null   object
#  2   age                             7429 non-null   int64
#  3   gender                          7429 non-null   object
#  4   country                         7429 non-null   object
#  5   urban_rural                     7429 non-null   object
#  6   income_level                    7429 non-null   object
#  7   employment_status               7429 non-null   object
#  8   education_level                 7429 non-null   object
#  9   relationship_status             7429 non-null   object
#  10  has_children                    7429 non-null   object
#  11  exercise_hours_per_week         7429 non-null   float64
# ...

# %%
df.describe().astype(int)
# Out:
#        user_id   age  exercise_hours_per_week  sleep_hours_per_night  \
# count     7429  7429                     7429                   7429
# mean      9280    39                        7                      7
# std       7510    15                        3                      3
# min          1    13                        0                      3
# 25%       1858    26                        4                      6
# 50%       3715    39                        6                      7
# 75%      16723    52                        9                      7
# max      18580    65                       20                    261
#
#        perceived_stress_score  self_reported_happiness  body_mass_index  \
# count                    7428                     7428             7428
# mean                       19                        5               25
# std                        11                        3                4
# ...

# %%
df.isnull().sum()
# Out:
# user_id                           0
# app_name                          0
# age                               0
# gender                            0
# country                           0
# urban_rural                       0
# income_level                      0
# employment_status                 0
# education_level                   0
# relationship_status               0
# has_children                      0
# exercise_hours_per_week           0
# sleep_hours_per_night             0
# diet_quality                      1
# smoking                           1
# alcohol_frequency                 1
# perceived_stress_score            1
# self_reported_happiness           1
# body_mass_index                   1
# blood_pressure_systolic           1
# blood_pressure_diastolic          1
# daily_steps_count                 1
# weekly_work_hours                 1
# hobbies_count                     1
# social_events_per_month           1
# books_read_per_year               1
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#       user_id   app_name  age gender country urban_rural income_level  \
# 3720     3721  Instagram   38   Male   Japan       Urban         High
# 7428    18580  Instagram   42   Male   India       Urban         High
#
#      employment_status education_level relationship_status  ...  \
# 3720           Student      Some coll4                   5  ...
# 7428           Student    Some college              Single  ...
#
#      last_login_date  average_session_length_minutes  content_type_preference  \
# 3720             NaN                             NaN                      NaN
# 7428             NaN                             NaN                      NaN
#
#      preferred_content_theme privacy_setting_level two_factor_auth_enabled  \
# 3720                     NaN                   NaN                     NaN
# 7428                     NaN                   NaN                     NaN
#
#       biometric_login_used  linked_accounts_count  subscription_status  \
# ...

# %%
df.drop(3720,inplace=True)

# %%
df.drop(7428,inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# ...

# %%
df.isnull().sum()
# Out:
# user_id                           0
# app_name                          0
# age                               0
# gender                            0
# country                           0
# urban_rural                       0
# income_level                      0
# employment_status                 0
# education_level                   0
# relationship_status               0
# has_children                      0
# exercise_hours_per_week           0
# sleep_hours_per_night             0
# diet_quality                      0
# smoking                           0
# alcohol_frequency                 0
# perceived_stress_score            0
# self_reported_happiness           0
# body_mass_index                   0
# blood_pressure_systolic           0
# blood_pressure_diastolic          0
# daily_steps_count                 0
# weekly_work_hours                 0
# hobbies_count                     0
# social_events_per_month           0
# books_read_per_year               0
# ...

# %%
df[["age","time_on_feed_per_day"]].plot(kind="box")
# Out:
# <Axes: >

# %%
df["time_on_feed_per_day"].max()
# Out:
# 295.0

# %%
df.describe().astype(int)
# Out:
#        user_id   age  exercise_hours_per_week  sleep_hours_per_night  \
# count     7427  7427                     7427                   7427
# mean      9280    39                        7                      7
# std       7510    15                        3                      1
# min          1    13                        0                      3
# 25%       1857    26                        4                      6
# 50%       3714    39                        6                      7
# 75%      16722    52                        9                      7
# max      18579    65                       20                     10
#
#        perceived_stress_score  self_reported_happiness  body_mass_index  \
# count                    7427                     7427             7427
# mean                       19                        5               25
# std                        11                        2                4
# ...

# %%
df[["age","perceived_stress_score"]].plot(kind="box")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3749/275666437.py in <cell line: 0>()
# ----> 1 df[["age","perceived_stress_score"]].plot(kind="box")
#
# NameError: name 'df' is not defined
